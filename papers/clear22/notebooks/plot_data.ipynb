# %%
import subprocess
import datetime
import os

import pandas as pd
from datetime import datetime


def gen_exec(cmd, check_return: bool = False):
    popen = subprocess.Popen(cmd, stdout=subprocess.PIPE, universal_newlines=True)
    for stdout_line in iter(popen.stdout.readline, ""):
        yield stdout_line
    popen.stdout.close()
    return_code = popen.wait()
    if return_code and check_return:
        raise subprocess.CalledProcessError(return_code, cmd)


def exec_bash(cmd: str, check_return: bool = False):
    return [s for s in gen_exec(cmd.split(), check_return)]
    
def exec_bash_print(cmd: str, check_return: bool = False):
    for path in gen_exec(cmd.split(), check_return):
        print(path, end="")
        
def strtime():
    return datetime.now().strftime("%y%m%d_%H%M%S")



from pathlib import Path

prj_path = Path(str(Path("../../../").resolve())+"/")
exp_folder = Path(prj_path, "papers/clear22/")
res_folder = Path(exp_folder, "output")
model_folder = Path(exp_folder, "models")

jar_file = Path(prj_path, "target/credici-0.1.3-SNAPSHOT-jar-with-dependencies.jar")
javafile = Path(exp_folder, "Experiments.java")
#java = "/Library/Java/JavaVirtualMachines/openjdk-12.0.1.jdk/Contents/Home/bin/java"
java = "java"


print(prj_path)
print(exp_folder)
print(res_folder)
print(model_folder)

print(jar_file)
# Out:
# /root/dev/credici
# /root/dev/credici/papers/clear22
# /root/dev/credici/papers/clear22/output
# /root/dev/credici/papers/clear22/models
# /root/dev/credici/target/credici-0.1.3-SNAPSHOT-jar-with-dependencies.jar

# %%
labels = ["211017_202416", "211017_202423", "211017_202430"] # without prop s=1

# %%
from collections.abc import Iterable
import numpy as np


#def load_data():

F = [Path(res_folder, l) for l in labels] 

res_list = []

for output_folder in F:
    resfiles = [f for f in os.listdir(output_folder) if f.endswith(".py")]

    for r in resfiles:
        try:
            exec(Path(output_folder, r).read_text())
            res_list.append(results)
        except Exception:
            print(f"error in {r}")

print(len(res_list))



def to_pandas(res_dict):

    simple_cols = [c for c in res_dict.keys() if not isinstance(res_dict[c], Iterable) or isinstance(res_dict[c], str)]
    df1 = pd.DataFrame.from_dict({k:[res_dict[k]] for k in simple_cols})
    list_cols = [c for c in res_dict.keys() if c not in simple_cols]

    if len(list_cols)>1:
        df2 = pd.DataFrame.from_dict({k:res_dict[k] for k in list_cols})
        df = pd.concat([pd.concat([df1]*len(df2)).reset_index(drop=True), df2], axis=1)

    else:
        df = df1    

    df = df.reset_index(drop=False)
    df = df.rename(columns = dict(index="numPoints"))

    df["numPoints"] += 1

    df.columns

    columns = ['seed', 'markovian','error', 'nEndo','nExo', 'exoTW', 'errorMsg', 'folder', 'file', 'groundtruth',
              'timeBuild', 'timeExact', 'timeQuery',
              'pnsExact_l','pnsExact_u', 'pnsEM_l', 'pnsEM_u',  'numPoints','innerPoints', 'llkratio',
              'iterEM', 'probAvailable']

    columns = [c for c in columns if c in df.columns] + [c for c in df.columns if c not in columns]


    df = df[columns]
    return df

data = pd.concat([to_pandas(r) for r in res_list]).reset_index(drop=True)
# replace exact == -1 by NaN or None
data.loc[data.pnsExact_l == -1, "pnsExact_l"] = np.nan
data.loc[data.pnsExact_u == -1, "pnsExact_u"] = np.nan

# add exactEvaluable 

data["exact_eval"] = ~data["pnsExact_l"].isna()


# calculate RMSE

def rmse_pns(t): return np.sqrt((t["pnsEM_l"] - t["pnsExact_l"])**2 + (t["pnsEM_u"] - t["pnsExact_u"])**2)
def interval_size(t): return t["pnsEM_u"] - t["pnsEM_l"]
def get_type(t):
    if t["markovian"]:
        return "markovian"
    elif t["exoTW"]<2:
        return "quasi"
    else:
        return "non-quasi"
        

data["rmse_pns"] = data.apply(rmse_pns, axis=1)
data["interval_size"] = data.apply(interval_size, axis=1)
data["type"] = data.apply(get_type, axis=1)

data["id"] = (data["folder"] + "_"+ data["file"]).str.replace(".uai", "")

data
# Out:
# 88
# <ipython-input-24-39f9dc875862>:83: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["id"] = (data["folder"] + "_"+ data["file"]).str.replace(".uai", "")
#      seed  markovian  error  nEndo  nExo  exoTW  \
# 0       0       True   True     15    15      1
# 1       0       True   True     10    10      1
# 2       0       True  False      5     5      1
# 3       0       True  False      5     5      1
# 4       0       True  False      5     5      1
# ..    ...        ...    ...    ...   ...    ...
# 331     0      False  False      5     3      1
# 332     0      False  False      5     3      1
# 333     0      False  False      5     3      1
# 334     0      False  False      5     3      1
# 335     0      False   True     15     9      1
#
#                                   errorMsg folder                        file  \
# 0    java.util.concurrent.TimeoutException     s0  chain_twExo0_nEndo15_5.uai
# 1    java.util.concurrent.TimeoutException     s0  chain_twExo0_nEndo10_2.uai
# 2                                              s0   chain_twExo0_nEndo5_3.uai
# 3                                              s0   chain_twExo0_nEndo5_3.uai
# 4                                              s0   chain_twExo0_nEndo5_3.uai
# ..                                     ...    ...                         ...
# 331                                           s1b  chain_twExo1_nEndo5_12.uai
# 332                                           s1b  chain_twExo1_nEndo5_12.uai
# 333                                           s1b  chain_twExo1_nEndo5_12.uai
# 334                                           s1b  chain_twExo1_nEndo5_12.uai
# 335  java.util.concurrent.TimeoutException    s1b  chain_twExo1_nEndo15_1.uai
#
#      numPoints  ...  datasize   aceEM_l  convPoints   timeEM   aceEM_u  \
# 0            1  ...       NaN       NaN         NaN      NaN       NaN
# 1            1  ...       NaN       NaN         NaN      NaN       NaN
# 2            1  ...    1000.0 -0.975330        40.0    277.0  0.972141
# 3            2  ...    1000.0 -0.795907        27.0  41191.0  0.804744
# 4            3  ...    1000.0 -0.805501        23.0  78269.0  0.805447
# ..         ...  ...       ...       ...         ...      ...       ...
# 331          6  ...    1000.0 -0.011490        20.0  45259.0  0.040790
# 332          7  ...    1000.0 -0.018704        44.0  45205.0  0.096065
# 333          8  ...    1000.0 -0.121573        30.0  49253.0 -0.000243
# 334          9  ...    1000.0 -0.086552         7.0  30890.0 -0.000036
# 335          1  ...       NaN       NaN         NaN      NaN       NaN
#
#      exact_eval  rmse_pns  interval_size       type  \
# 0         False       NaN            NaN  markovian
# 1         False       NaN            NaN  markovian
# 2          True  0.236784       0.241234  markovian
# 3          True  0.073763       0.078222  markovian
# 4          True  0.166027       0.170490  markovian
# ..          ...       ...            ...        ...
# 331        True  0.016201       0.119040      quasi
# 332        True  0.035094       0.134218      quasi
# 333        True  0.002134       0.103906      quasi
# 334        True  0.008154       0.095127      quasi
# 335       False       NaN            NaN      quasi
#
#                              id
# 0     s0_chain_twExo0_nEndo15_5
# 1     s0_chain_twExo0_nEndo10_2
# 2      s0_chain_twExo0_nEndo5_3
# 3      s0_chain_twExo0_nEndo5_3
# 4      s0_chain_twExo0_nEndo5_3
# ..                          ...
# 331  s1b_chain_twExo1_nEndo5_12
# 332  s1b_chain_twExo1_nEndo5_12
# 333  s1b_chain_twExo1_nEndo5_12
# 334  s1b_chain_twExo1_nEndo5_12
# 335  s1b_chain_twExo1_nEndo15_1
#
# [336 rows x 30 columns]

# %%
# Out:
#      seed  markovian  error  nEndo  nExo  exoTW errorMsg folder  \
# 2       0       True  False      5     5      1              s0
# 3       0       True  False      5     5      1              s0
# 4       0       True  False      5     5      1              s0
# 5       0       True  False      5     5      1              s0
# 6       0       True  False      5     5      1              s0
# ..    ...        ...    ...    ...   ...    ...      ...    ...
# 330     0      False  False      5     3      1             s1b
# 331     0      False  False      5     3      1             s1b
# 332     0      False  False      5     3      1             s1b
# 333     0      False  False      5     3      1             s1b
# 334     0      False  False      5     3      1             s1b
#
#                            file  numPoints  ...  datasize   aceEM_l  \
# 2     chain_twExo0_nEndo5_3.uai          1  ...    1000.0 -0.975330
# 3     chain_twExo0_nEndo5_3.uai          2  ...    1000.0 -0.795907
# 4     chain_twExo0_nEndo5_3.uai          3  ...    1000.0 -0.805501
# 5     chain_twExo0_nEndo5_3.uai          4  ...    1000.0 -0.561070
# 6     chain_twExo0_nEndo5_3.uai          5  ...    1000.0 -0.348005
# ..                          ...        ...  ...       ...       ...
# 330  chain_twExo1_nEndo5_12.uai          5  ...    1000.0 -0.014681
# 331  chain_twExo1_nEndo5_12.uai          6  ...    1000.0 -0.011490
# 332  chain_twExo1_nEndo5_12.uai          7  ...    1000.0 -0.018704
# 333  chain_twExo1_nEndo5_12.uai          8  ...    1000.0 -0.121573
# 334  chain_twExo1_nEndo5_12.uai          9  ...    1000.0 -0.086552
#
#      convPoints    timeEM   aceEM_u  exact_eval  rmse_pns  interval_size  \
# 2          40.0     277.0  0.972141        True  0.236784       0.241234
# 3          27.0   41191.0  0.804744        True  0.073763       0.078222
# 4          23.0   78269.0  0.805447        True  0.166027       0.170490
# 5          42.0   96303.0  0.558513        True  0.001773       0.004777
# 6          31.0  114290.0  0.346814        True  0.000921       0.003420
# ..          ...       ...       ...         ...       ...            ...
# 330        31.0   45378.0  0.095853        True  0.021920       0.124073
# 331        20.0   45259.0  0.040790        True  0.016201       0.119040
# 332        44.0   45205.0  0.096065        True  0.035094       0.134218
# 333        30.0   49253.0 -0.000243        True  0.002134       0.103906
# 334         7.0   30890.0 -0.000036        True  0.008154       0.095127
#
#           type                          id
# 2    markovian    s0_chain_twExo0_nEndo5_3
# 3    markovian    s0_chain_twExo0_nEndo5_3
# 4    markovian    s0_chain_twExo0_nEndo5_3
# 5    markovian    s0_chain_twExo0_nEndo5_3
# 6    markovian    s0_chain_twExo0_nEndo5_3
# ..         ...                         ...
# 330      quasi  s1b_chain_twExo1_nEndo5_12
# 331      quasi  s1b_chain_twExo1_nEndo5_12
# 332      quasi  s1b_chain_twExo1_nEndo5_12
# 333      quasi  s1b_chain_twExo1_nEndo5_12
# 334      quasi  s1b_chain_twExo1_nEndo5_12
#
# [279 rows x 30 columns]

# %%
# plot RMSE vs numPoints
import matplotlib.pyplot as plt

# plot 3 a line for each nEndo

#df= data.loc[(data.markovian==True) & (data.exoTW==1)]
#df = data.loc[(data.markovian==False) & (data.exoTW==2)]
title=None
nEndo = [5,10]

def plot(df, title=None, nEndo = None, printVals=False, yval="rmse_pns"):
    print(len(df[df.numPoints==1]))

    df = df[["folder","file", "numPoints", yval, "exact_eval", "nEndo"]]
    
    df = df.dropna()
    
    print("=======")
    for t in df[df.numPoints==1].iterrows():
        print(f"{t[1]['folder']}/{t[1]['file']}")
        #print(t)
    print("=======")
    
    
    df = df.dropna()

    print(len(df[df.numPoints==1]))
    



    for n in nEndo:
        print(len(df.loc[(df.numPoints==1) & (df.nEndo==n)]))
        


    group_vars = ["numPoints"]

    if nEndo is not None: 
        group_vars +=  ["nEndo"]

    group = df[["numPoints", yval, "exact_eval", "nEndo"]].groupby(group_vars)

    df = group.mean()

    fig, ax = plt.subplots()

    if nEndo is not None:
        df = df.reset_index()
        for n in nEndo:
            y = df[df.nEndo== n][yval]
            x = df[df.nEndo== n]["numPoints"]
            plt.plot(x,y, label=f"#endog = {int(n)}")

            if print:
                print()

                for t in np.vstack([x.values.T, y.values.T]).T:
                    print(f"{int(t[0])}\t{t[1]}")
                print()
    else:
        #print(df.columns)
        x = df[yval]
        #print
        #y = df["numPoints"]

        plt.plot(x)


    ax.legend()

    ax.set(ylabel=yval, xlabel='EM runs',
           title=title, #ylim=[-0.01,0.05]
          )
    ax.grid()

# %%
plot(data.loc[(data.markovian==True) & (data.exoTW==1)], nEndo = [5], title = "Markovian",
     printVals=False, yval="interval_size")
#data["exact_eval"]
#data.loc[(data.markovian==False) ]
# Out:
# 43
# =======
# s0/chain_twExo0_nEndo5_3.uai
# s0/chain_twExo0_nEndo5_4.uai
# s0/chain_twExo0_nEndo5_9.uai
# s0/chain_twExo0_nEndo5_0.uai
# s0/chain_twExo0_nEndo5_8.uai
# s0/chain_twExo0_nEndo5_1.uai
# s0/chain_twExo0_nEndo5_2.uai
# s0/chain_twExo0_nEndo5_6.uai
# s0/chain_twExo0_nEndo5_6.uai
# s0/chain_twExo0_nEndo5_7.uai
# s1b/chain_twExo0_nEndo5_17.uai
# s1b/chain_twExo0_nEndo5_16.uai
# s1b/chain_twExo0_nEndo5_12.uai
# s1b/chain_twExo0_nEndo5_12.uai
# s1b/chain_twExo0_nEndo5_13.uai
# =======
# 15
# 15
#
# 1	0.30838721175052514
# 2	0.2642176045391632
# 3	0.1973785806383749
# 4	0.1644090039332031
# 5	0.10260425207640299
# 6	0.06843018213290634
# 7	0.058454227677403096
# 8	0.05651356637127816
# 9	0.057738265107602715

# %%
data.columns
# Out:
# Index(['seed', 'markovian', 'error', 'nEndo', 'nExo', 'exoTW', 'errorMsg',
#        'folder', 'file', 'groundtruth', 'timeBuild', 'timeExact', 'timeQuery',
#        'pnsExact_l', 'pnsExact_u', 'pnsEM_l', 'pnsEM_u', 'numPoints',
#        'innerPoints', 'llkratio', 'iterEM', 'compatible', 'klpq', 'klsym',
#        'klqp', 'exact_eval', 'rmse_pns', 'interval_size', 'type', 'id',
#        'maxPoints', 'timePerRun', 'meanRatio', 'maxRatio', 'meanklpq'],
#       dtype='object')

# %%
plot_rmse(data.loc[(data.markovian==False)  & (data.exoTW==1) & ((data.nEndo > 0))],
          #split_endo=False,
          title = "Quasi-markovian",
          nEndo = [5,7,10], printVals=True)
# Out:
# 45
# =======
# s1a/chain_twExo1_nEndo10_8.uai
# s1a/chain_twExo1_nEndo10_3.uai
# s1a/chain_twExo1_nEndo15_4.uai
# s1a/chain_twExo1_nEndo5_3.uai
# s1a/chain_twExo1_nEndo10_7.uai
# s1a/chain_twExo1_nEndo5_0.uai
# s1a/chain_twExo1_nEndo15_6.uai
# s1a/chain_twExo1_nEndo15_3.uai
# s1a/chain_twExo1_nEndo5_5.uai
# s1a/chain_twExo1_nEndo5_6.uai
# s1a/chain_twExo1_nEndo10_6.uai
# s1a/chain_twExo1_nEndo10_4.uai
# s1a/chain_twExo1_nEndo15_0.uai
# s1a/chain_twExo1_nEndo5_9.uai
# s1a/chain_twExo1_nEndo10_0.uai
# s1a/chain_twExo1_nEndo15_2.uai
# s1a/chain_twExo1_nEndo5_7.uai
# s1a/chain_twExo1_nEndo15_8.uai
# s1a/chain_twExo1_nEndo10_5.uai
# s1a/chain_twExo1_nEndo10_9.uai
# s1a/chain_twExo1_nEndo10_1.uai
# s1a/chain_twExo1_nEndo5_4.uai
# s1a/chain_twExo1_nEndo5_1.uai
# s1a/chain_twExo1_nEndo10_2.uai
# s1a/chain_twExo1_nEndo5_2.uai
# s1a/chain_twExo1_nEndo15_5.uai
# s1a/chain_twExo1_nEndo15_7.uai
# s1a/chain_twExo1_nEndo5_8.uai
# s1a/chain_twExo1_nEndo15_9.uai
# s1b/chain_twExo1_nEndo10_14.uai
# s1b/chain_twExo1_nEndo5_15.uai
# s1b/chain_twExo1_nEndo5_19.uai
# s1b/chain_twExo1_nEndo15_17.uai
# s1b/chain_twExo1_nEndo10_12.uai
# s1b/chain_twExo1_nEndo15_18.uai
# s1b/chain_twExo1_nEndo15_19.uai
# s1b/chain_twExo1_nEndo5_18.uai
# s1b/chain_twExo1_nEndo5_17.uai
# s1b/chain_twExo1_nEndo5_10.uai
# s1b/chain_twExo1_nEndo15_15.uai
# s1b/chain_twExo1_nEndo15_16.uai
# s1b/chain_twExo1_nEndo10_16.uai
# s1b/chain_twExo1_nEndo10_17.uai
# s1b/chain_twExo1_nEndo5_12.uai
# s1b/chain_twExo1_nEndo15_1.uai
# =======
# 16
# 16
# 0
# 0
#
# 1	0.2744947105434302
# 2	0.21099179565544304
# 3	0.13846683885477898
# 4	0.10694426483768797
# 5	0.044496421747190575
# 6	0.042090482658765103
# 7	0.01161852575923358
# 8	0.006927747650635174
# 9	0.0040594408691643664

# %%
sum([29,33,18,20,33,25])
# Out:
# 158

# %%
plot_rmse(data.loc[(data.markovian==False) & (data.exoTW==2)],  
          nEndo = [5,7,10], 
          title="Non-markovian TW=2", printVals=True)
# Out:
# 215
# =======
# s2/chain_twExo2_nEndo15_17.uai
# s2/chain_twExo2_nEndo5_18.uai
# s2/chain_twExo2_nEndo5_1.uai
# s2/chain_twExo2_nEndo15_10.uai
# s2/chain_twExo2_nEndo5_5.uai
# s2/chain_twExo2_nEndo5_6.uai
# s2/chain_twExo2_nEndo15_19.uai
# s2/chain_twExo2_nEndo5_19.uai
# s2/chain_twExo2_nEndo15_8.uai
# s2/chain_twExo2_nEndo5_8.uai
# s2/chain_twExo2_nEndo15_6.uai
# s2/chain_twExo2_nEndo5_13.uai
# s2/chain_twExo2_nEndo15_2.uai
# s2/chain_twExo2_nEndo5_17.uai
# s2/chain_twExo2_nEndo15_9.uai
# s2/chain_twExo2_nEndo15_5.uai
# s2/chain_twExo2_nEndo15_15.uai
# s2/chain_twExo2_nEndo5_2.uai
# s2/chain_twExo2_nEndo15_3.uai
# s2/chain_twExo2_nEndo5_12.uai
# s2/chain_twExo2_nEndo5_15.uai
# s2/chain_twExo2_nEndo15_4.uai
# s2/chain_twExo2_nEndo15_13.uai
# s2/chain_twExo2_nEndo5_3.uai
# s2/chain_twExo2_nEndo5_10.uai
# s2/chain_twExo2_nEndo15_14.uai
# s2/chain_twExo2_nEndo5_9.uai
# s2/chain_twExo2_nEndo15_18.uai
# s2/chain_twExo2_nEndo5_7.uai
# s2/chain_twExo2_nEndo15_16.uai
# s2/chain_twExo2_nEndo5_4.uai
# s2/chain_twExo2_nEndo5_16.uai
# s2/chain_twExo2_nEndo15_12.uai
# s2/chain_twExo2_nEndo15_0.uai
# s2/chain_twExo2_nEndo15_11.uai
# s2/chain_twExo2_nEndo5_14.uai
# s2/chain_twExo2_nEndo15_1.uai
# s2/chain_twExo2_nEndo5_0.uai
# s2/chain_twExo2_nEndo15_7.uai
# s2/chain_twExo2_nEndo5_11.uai
# s2_2/chain_twExo2_nEndo5_28.uai
# s2_2/chain_twExo2_nEndo15_30.uai
# s2_2/chain_twExo2_nEndo15_35.uai
# s2_2/chain_twExo2_nEndo5_39.uai
# s2_2/chain_twExo2_nEndo5_37.uai
# s2_2/chain_twExo2_nEndo5_23.uai
# s2_2/chain_twExo2_nEndo5_35.uai
# s2_2/chain_twExo2_nEndo5_25.uai
# s2_2/chain_twExo2_nEndo5_21.uai
# s2_2/chain_twExo2_nEndo15_21.uai
# s2_2/chain_twExo2_nEndo15_28.uai
# s2_2/chain_twExo2_nEndo5_34.uai
# s2_2/chain_twExo2_nEndo15_25.uai
# s2_2/chain_twExo2_nEndo15_23.uai
# s2_2/chain_twExo2_nEndo5_30.uai
# s2_2/chain_twExo2_nEndo5_31.uai
# s2_2/chain_twExo2_nEndo15_32.uai
# 17	0.00037209839850656153
# 18	0.00035894701883090285
# 19	0.0003572286717540354
# 20	0.0003447516205928922
# 21	0.00033710348799335737
# 22	0.0002835971831288319
# 23	0.0002835928262404677
# 24	0.00023976205249019703
# 25	0.00023965451330339171
# 26	0.00023965451330339171
# 27	0.00023965451330339171
# 28	0.0002182821138625045
# 29	0.00021729423135872106
# 30	0.0
#
#
# 1	0.0009099817191841699
# 2	0.0003635320498397803
# 3	0.00030239218150963503
# 4	0.00029533140233534394
# 5	0.0002800572000243623
# 6	0.00026448353556237996
# 7	0.0002569623304038956
# 8	0.00025534302993474137
# 9	0.00025527855132885714
# 10	0.00021335527770794494
# 11	0.0002022649590056434
# 12	0.0001533652031731199
# 13	0.00012330857013115957
# 14	0.00012326335468319116
# 15	0.00011458731133084406
# 16	0.00011366132888439981
# 17	7.578701503365634e-05
# 18	7.422271015320467e-05
# 19	7.313232764010746e-05
# 20	7.149902825222893e-05
# 21	6.850210143458125e-05
# 22	6.803180616212153e-05
# 23	6.56883595563686e-05
# 24	6.56883595563686e-05
# 25	6.422851278489172e-05
# 26	6.081734482869679e-05
# 27	6.081734482869679e-05
# 28	5.960485146583896e-05
# 29	0.0
# 30	0.0

# %%
195+132+133
# Out:
# 460

# %%
df = data.loc[data.nEndo<15]
df = df[["interval_size", "type", "nEndo"]].dropna()

group = df.groupby(["nEndo", "type"])
df = group.mean().reset_index()
fig, ax = plt.subplots()

vals = []

for t in df["type"].unique():
    y = df[df.type== t]["interval_size"]
    x = df[df.type== t]["nEndo"]
    plt.plot(x,y, label=f"{t}")
    
    print(t)
    print(y.values)
    #vals.append(y.values)

ax.legend()


#print(np.array(vals).T)

ax.set(ylabel='interval size', xlabel='# endog',
       title=title)
ax.grid()
# Out:
# markovian
# [0.01625261 0.00319382 0.00219375]
# non-quasi
# [0.05358728 0.00778531 0.00109947]
# quasi
# [3.26249581e-02 3.44368311e-02 1.94271142e-05]

# %%
df = data.loc[data.nEndo<15]
df = df[["timePerRun", "type", "nEndo"]].dropna()

group = df.groupby(["nEndo", "type"])
df = group.mean().reset_index()
fig, ax = plt.subplots()

#l = {"markvovian":"Markovian", "quasi":"Quasi-Markovian", "non-quasi":"Non-Quasi-Markovian"}
vals = dict()

for t in df["type"].unique():
    y = df[df.type== t]["timePerRun"]/1000
    x = df[df.type== t]["nEndo"]
    plt.plot(x,y, label=f"{t}")
    
    print(t)
    print(y.values)

ax.legend()

ax.set(ylabel='time (s.)', xlabel='# endog',
       title=title)
ax.grid()
# Out:
# markovian
# [ 18.77580809  62.80384501 242.83345227]
# non-quasi
# [ 23.08661797  73.37517647 319.31441885]
# quasi
# [ 11.14036452  28.69073882 108.80902865]

# %%
data.columns
# Out:
# Index(['seed', 'markovian', 'error', 'nEndo', 'nExo', 'exoTW', 'errorMsg',
#        'folder', 'file', 'groundtruth', 'timeBuild', 'timeExact', 'timeQuery',
#        'pnsExact_l', 'pnsExact_u', 'pnsEM_l', 'pnsEM_u', 'numPoints',
#        'innerPoints', 'llkratio', 'iterEM', 'compatible', 'klpq', 'klsym',
#        'klqp', 'exact_eval', 'rmse_pns', 'interval_size', 'type', 'id',
#        'maxPoints', 'timePerRun', 'meanRatio', 'maxRatio', 'meanklpq'],
#       dtype='object')

# %%
data.loc[(data.numPoints==20) & (data.interval_size>0.01) &  (data.markovian==False) &(data.exoTW==1) &(data.nEndo==5) & (data.rmse_pns<0.01)][["id", 'pnsExact_l', 'pnsExact_u', 'pnsEM_l', 'pnsEM_u']]
# Out:
#                                 id  pnsExact_l  pnsExact_u   pnsEM_l   pnsEM_u
# 641     s1b_chain_twExo1_nEndo5_15    0.000000    0.028796  0.000180  0.028527
# 881      s1a_chain_twExo1_nEndo5_4    0.000079    0.023753  0.000088  0.022804
# 2204  s1a_2_chain_twExo1_nEndo5_24    0.103005    0.117614  0.103043  0.117400
# 2344  s1a_2_chain_twExo1_nEndo5_28    0.000259    0.030201  0.002324  0.022229

# %%
#df = data.loc[(data.nEndo<15) & (data.type != "non-quasi")]
def plot_under_th(data, nEndo = (5,7,10,15), th=0.01, title=None):
    df = data
    df["under_th"] = df["rmse_pns"]<th
    df = df[["under_th", "numPoints", "nEndo"]].dropna()


    stats = pd.DataFrame(columns = ["numPoints", "nEndo", "under_th"])

    for p in list(df.numPoints.unique()):
        for n in nEndo:
            M = len(df[(df.numPoints==p) & (df.nEndo==n) & (df.under_th==True)])
            N = len(df[(df.numPoints==p) & (df.nEndo==n)])

            if N>0:
                #print(f"{M}/{N}")

                stats = stats.append(dict(numPoints=p, nEndo=n, under_th=M/N*100), ignore_index=True)
    stats = stats.sort_values("numPoints")

    fig, ax = plt.subplots()

    df = df.reset_index()

    for n in nEndo:
        y = stats[stats.nEndo== n]["under_th"]
        x = stats[stats.nEndo== n]["numPoints"]
        plt.plot(x,y, label=f"#endog = {int(n)}")


    ax.legend()

    ax.set(ylabel='% models', xlabel='# endog',
           title=title)
    ax.grid()

# %%
th = 0.01
plot_under_th(data.loc[(data.type == "markovian")],
              nEndo = [5,7,10],
              th = th,
              title="markovian")
# Out:
# <ipython-input-365-5ca6e57869ed>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["under_th"] = df["rmse_pns"]<th

# %%
plot_under_th(data.loc[(data.type == "quasi")],
              nEndo = [5,7,10],
              th = th,
              title="quasi-markovian")
# Out:
# <ipython-input-365-5ca6e57869ed>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["under_th"] = df["rmse_pns"]<th

# %%
plot_under_th(data.loc[(data.type == "non-quasi")],
              nEndo = [5,7,10],
              th = th,
              title="non quasi-markovian")
# Out:
# <ipython-input-365-5ca6e57869ed>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["under_th"] = df["rmse_pns"]<th

# %%
llk_info = pd.concat(
    [group.mean().rename(columns=dict(llkratio="avg_llkratio")),
     group.min().rename(columns=dict(llkratio="min_llkratio")),
     group.max().rename(columns=dict(llkratio="max_llkratio")),
    ],axis = 1)
     
    
llk_info = data[["id","markovian", "exoTW", "nEndo", "nExo", "exact_eval"]].groupby("id").mean().merge(llk_info, on="id")

llk_info

#llk_info.to_csv(Path(output_folder,"llk_info.csv"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-247-6599762508d2> in <module>
#       6
#       7
# ----> 8 llk_info = data[["id","markovian", "exoTW", "nEndo", "nExo", "exact_eval"]].groupby("id").mean().merge(llk_info, on="id")
#       9
#      10 llk_info
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    8193         from pandas.core.reshape.merge import merge
#    8194
# -> 8195         return merge(
#    8196             self,
#    8197             right,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     666             self.right_join_keys,
#     667             self.join_names,
# --> 668         ) = self._get_merge_keys()
#     669
#     670         # validate the merge keys dtypes. We may need to coerce
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1031                     if not is_rkey(rk):
#    1032                         if rk is not None:
# -> 1033                             right_keys.append(right._get_label_or_level_values(rk))
#    1034                         else:
#    1035                             # work-around for merge_asof(right_index=True)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1682             values = self.axes[axis].get_level_values(key)._values
#    1683         else:
# -> 1684             raise KeyError(key)
#    1685
#    1686         # Check for duplicates
#
# KeyError: 'id'

# %%
sum(llk_info["exact_eval"]==True)

# %%
sum(llk_info["exact_eval"]==False)

# %%
## Average llk-ratio when data is compatible
llk_info.loc[llk_info.exact_eval==True, "avg_llkratio"].hist()

# %%
## Average llk-ratio when data is not compatible
llk_info.loc[llk_info.exact_eval==False, "avg_llkratio"].hist()

# %%
## Average llk-ratio when data is compatible
llk_info.loc[(llk_info.exact_eval==True) & (llk_info.avg_llkratio>0.8), "avg_llkratio"].hist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-f6cc52ab1e41> in <module>
#       1 ## Average llk-ratio when data is compatible
# ----> 2 llk_info.loc[(llk_info.exact_eval==True) & (llk_info.avg_llkratio>0.8), "avg_llkratio"].hist()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'exact_eval'

# %%
## Average llk-ratio when data is compatible
llk_info.loc[(llk_info.exact_eval==False) & (llk_info.avg_llkratio>0.8), "avg_llkratio"].hist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-2cbc3b9e89c3> in <module>
#       1 ## Average llk-ratio when data is compatible
# ----> 2 llk_info.loc[(llk_info.exact_eval==False) & (llk_info.avg_llkratio>0.8), "avg_llkratio"].hist()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'exact_eval'

# %%
-float("inf")
# Out:
# -inf

# %%
# KLpq, KLsym  for compatible vs not compatible and mark and quasi-mark
data.columns
# Out:
# Index(['seed', 'markovian', 'error', 'nEndo', 'nExo', 'exoTW', 'errorMsg',
#        'folder', 'file', 'groundtruth', 'timeBuild', 'timeExact', 'timeQuery',
#        'pnsExact_l', 'pnsExact_u', 'pnsEM_l', 'pnsEM_u', 'numPoints',
#        'innerPoints', 'llkratio', 'iterEM', 'klpq', 'klsym', 'klqp',
#        'exact_eval', 'rmse_pns', 'id'],
#       dtype='object')

# %%
group = data[["id", 'klpq', 'klsym', 'klqp']].groupby("id")
kl_info = group.mean()
kl_info = data[["id","markovian", "exoTW", "nEndo", "nExo", "exact_eval"]].groupby("id").mean().merge(kl_info, on="id")
kl_info
# Out:
#                              exoTW  nEndo  nExo  exact_eval      klpq  \
# id
# set1_chain_twExo0_nEndo4_10    1.0    4.0   4.0        True  0.000698
# set1_chain_twExo0_nEndo4_16    1.0    4.0   4.0        True  0.000530
# set1_chain_twExo0_nEndo4_17    1.0    4.0   4.0        True  0.000826
# set1_chain_twExo0_nEndo4_18    1.0    4.0   4.0        True  0.000222
# set1_chain_twExo0_nEndo4_2     1.0    4.0   4.0        True  0.000834
# ...                            ...    ...   ...         ...       ...
# set3_chain_twExo3_nEndo6_3     3.0    6.0   6.0        True  0.003712
# set3_chain_twExo3_nEndo6_6     3.0    6.0   6.0        True  0.002410
# set3_chain_twExo3_nEndo6_7     NaN    NaN   NaN       False       NaN
# set3_chain_twExo3_nEndo6_8     3.0    6.0   6.0        True  0.000663
# set3_chain_twExo3_nEndo6_9     3.0    6.0   5.0        True  0.003145
#
#                                 klsym      klqp
# id
# set1_chain_twExo0_nEndo4_10  0.001294  0.000596
# set1_chain_twExo0_nEndo4_16  0.001069  0.000538
# set1_chain_twExo0_nEndo4_17  0.001604  0.000778
# set1_chain_twExo0_nEndo4_18  0.000444  0.000222
# set1_chain_twExo0_nEndo4_2   0.001679  0.000846
# ...                               ...       ...
# set3_chain_twExo3_nEndo6_3   0.007408  0.003696
# set3_chain_twExo3_nEndo6_6   0.004724  0.002314
# set3_chain_twExo3_nEndo6_7        NaN       NaN
# set3_chain_twExo3_nEndo6_8   0.001301  0.000637
# set3_chain_twExo3_nEndo6_9   0.007154  0.004008
#
# [130 rows x 7 columns]

# %%
kl_info.loc[llk_info.exact_eval==True, "klpq"].hist()
# Out:
# <AxesSubplot:>

# %%
kl_info.loc[llk_info.exact_eval==False, "klpq"].hist()
# Out:
# <AxesSubplot:>

# %%
i=3
data[data.groundtruth == "saturation"][['pnsExact_l',
       'pnsExact_u', 'pnsEM_l', 'pnsEM_u', 'numPoints', 'klpq', 'llkratio']].iloc[i*20:i*20+20]
# Out:
#      pnsExact_l  pnsExact_u   pnsEM_l   pnsEM_u  numPoints      klpq  llkratio
# 120    0.000301    0.002791  0.001974  0.001974          1  0.006496  0.973080
# 121    0.000301    0.002791  0.001974  0.002767          2  0.005738  0.976149
# 122    0.000301    0.002791  0.000301  0.002767          3  0.008010  0.967015
# 123    0.000301    0.002791  0.000301  0.002767          4  0.004603  0.980774
# 124    0.000301    0.002791  0.000301  0.002767          5  0.004695  0.980398
# 125    0.000301    0.002791  0.000301  0.002767          6  0.006142  0.974513
# 126    0.000301    0.002791  0.000301  0.002767          7  0.002760  0.988385
# 127    0.000301    0.002791  0.000301  0.002767          8  0.003584  0.984969
# 128    0.000301    0.002791  0.000301  0.002767          9  0.001494  0.993678
# 129    0.000301    0.002791  0.000301  0.002767         10  0.003892  0.983696
# 130    0.000301    0.002791  0.000301  0.002767         11  0.003932  0.983531
# 131    0.000301    0.002791  0.000301  0.002767         12  0.007071  0.970768
# 132    0.000301    0.002791  0.000301  0.002767         13  0.005637  0.976556
# 133    0.000301    0.002791  0.000301  0.002767         14  0.003896  0.983679
# 134    0.000301    0.002791  0.000301  0.002791         15  0.004409  0.981569
# 135    0.000301    0.002791  0.000301  0.002791         16  0.004914  0.979504
# 136    0.000301    0.002791  0.000301  0.002791         17  0.007661  0.968405
# 137    0.000301    0.002791  0.000301  0.002791         18  0.004407  0.981578
# 138    0.000301    0.002791  0.000301  0.002791         19  0.006663  0.972410
# 139    0.000301    0.002791  0.000301  0.002791         20  0.009581  0.960800

# %%
data.columns
# Out:
# Index(['seed', 'markovian', 'error', 'nEndo', 'nExo', 'exoTW', 'errorMsg',
#        'folder', 'file', 'groundtruth', 'timeBuild', 'timeQuery', 'pnsExact_l',
#        'pnsExact_u', 'pnsEM_l', 'pnsEM_u', 'numPoints', 'innerPoints',
#        'llkratio', 'iterEM', 'klpq', 'klsym', 'klqp', 'timeExact',
#        'exact_eval', 'rmse_pns', 'id'],
#       dtype='object')

# %%
## copy all the used models
