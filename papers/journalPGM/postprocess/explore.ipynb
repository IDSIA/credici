# %%
import compute_convergence
import data
import glob
import seaborn as sns
import numpy as np
import pandas as pd
from functools import partial
sns.set_theme()

# %%
d = pd.read_json("pns_hybrid.json")

# %%
d
# Out:
#                                                    pns     pns_l     pns_u  \
# 0    [0.0636197601, 0.07317992820000001, 0.06052482...  0.004233  0.090177
# 1    [0.0746556238, 0.062516759, 0.0699946373000000...  0.005543  0.088843
# 2    [0.075160247, 0.025405193200000002, 0.02932763...  0.005941  0.091663
# 3    [0.4087112356, 0.041110435, 0.2392682375, 0.05...  0.000407  0.799642
# 8    [0.0137977345, 0.0558230994, 0.002689317, 0.00...  0.000164  0.120679
# ..                                                 ...       ...       ...
# 355  [0.13645888, 0.1055364052, 0.11103335210000001...  0.000025  0.185936
# 356  [0.0103829157, 0.0572887352, 0.0025743054, 0.0...  0.000038  0.124301
# 357  [0.0163811641, 0.0021021219, 0.0010111646, 0.0...  0.000050  0.133207
# 358  [0.0640804655, 0.026749595600000002, 0.0506952...  0.000012  0.133417
# 359  [0.0153652405, 0.051512936200000005, 0.0065446...  0.000001  0.127864
#
#                                                   file    model_type
# ...

# %%
import convergence as c
