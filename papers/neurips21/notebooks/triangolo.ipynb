# %%
import networkx as nx

# %%
edges = [(8,0), (7,0), (2,0), (11,0), (9,2), (1,3), (8,5), (3,6), (10,6), (1,6), (5,7), (1,7), (10,8), (1,8), (1,9), (4,10), (1,10), (6,11)]

# %%
names = ["Death", "Symptoms", "PPreference", "FAwareness", "Age", "Practitioner", "FSystem", "Triangolo", "Hospital", "PAwareness", "Karnofsky", "FPreference"]


edges_names = [(names[t[0]],names[t[1]]) for t in edges]

# %%
G = nx.DiGraph(edges_names)

# %%
nx.draw_planar(G, with_labels = True)
